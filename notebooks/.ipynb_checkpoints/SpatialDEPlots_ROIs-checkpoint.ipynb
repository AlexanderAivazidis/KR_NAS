# %% [markdown]
# In this notebook, we extract significantly spatially varying genes and show them in three clusters.

# %% [markdown]
# Load relevant packages, including SpatialDE:

# %%
import sys,os
path = '/nfs/team283/aa16/InSituCellTools/'
os.chdir(path)
sys.path.append(path)

# %%
# %pylab inline
import pandas as pd
import NaiveDE
import SpatialDE
import statsmodels.stats.multitest as multi
import scipy.stats as ss
import pickle as pickle
import scipy as sc
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Load the data and remove negative probes for this analysis:

# %%
adata = pickle.load(open('data/nanostringWTA_fetailBrain_AnnData.p',  "rb"))
adata = adata[:,adata.var_names != 'NegProbe-WTX']

# %% [markdown]
# Choose the data from 19pcw replicates at radial position 2:

# %%
subset_19pcw = [adata.obs['Radial_position'][i] == 2 and 
                adata.obs['age'][i] == '19pcw' for i in range(np.shape(adata.obs)[0])]

# %% [markdown]
# Prepare data for spatialDE:

# %%
adata.layers['Stabilized'] = NaiveDE.stabilize(adata.X)
adata.obs['TotalCounts'] = np.sum(adata.X, axis = 1)

adata.layers['TotalCountsRegressed'] = NaiveDE.regress_out(adata.obs, adata.layers['Stabilized'].T, 'np.log(TotalCounts)').T

input_data = pd.DataFrame(adata.layers['TotalCountsRegressed'][subset_19pcw,:], index = adata.obs['Sanger_sampleID'][subset_19pcw],
                   columns = adata.var_names)
input_coordinates = adata.obs.loc[subset_19pcw,('Radial_position', 'VCDepth')].rename(columns={"Radial_position": "x", "VCDepth": "y"})

# %%
adata.layers['CPM'] = np.asarray([adata.X[i,:]/adata.obs['TotalCounts'][i] for i in range(len(adata.obs['TotalCounts']))])*10**6
adata.layers['zscore_19pcw'] = sc.stats.zscore(np.log2(adata.layers['CPM']+1), axis = 0)

# %% [markdown]
# Run spatialDE:

# %%
results = SpatialDE.run(input_coordinates, input_data)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Models: ', max=10.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, max=15182.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15182.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15182.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15182.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15182.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15182.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15182.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15182.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15182.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15182.0), HTML(value='')))

# %% [markdown]
# Get list of all spatially varying genes:

# %%
threshold = 0.05
print('significance threshold (fdr/qval):', threshold)
results = results.sort_values('qval')
genes_ranked = np.array(results['g'])
genes_significant_fdr = genes_ranked[multi.multipletests(results['pval'], method = 'fdr_bh')[1] < threshold]
genes_significant_qval = genes_ranked[results['qval'] < 0.05]
print('genes significant (fdr):', len(genes_significant_fdr))
print('genes significant (qval):', len(genes_significant_qval))
overlap = sum([genes_significant_fdr[i] in genes_significant_qval for i in range(len(genes_significant_fdr))])/len(genes_significant_fdr)
print('overlap_fdr_qval:', overlap)
percent_significant_fdr = len(genes_significant_fdr)/len(genes_ranked)
percent_significant_qval = len(genes_significant_qval)/len(genes_ranked)
print('percent_significant_fdr:', percent_significant_fdr)
print('percent_significant_qval:', percent_significant_qval)
# Out:
# significance threshold (fdr/qval): 0.05
# genes significant (fdr): 6354
# genes significant (qval): 11652
# overlap_fdr_qval: 1.0
# percent_significant_fdr: 0.41852193386905545
# percent_significant_qval: 0.7674878145171914

# %% [markdown]
# Cluster genes:

# %%
n_patterns = 3
results_patterns = SpatialDE.aeh.spatial_patterns(input_coordinates, input_data, results.loc[results['qval'] < 0.05,:], C=n_patterns, l=0.2, verbosity=1, maxiter= 1000)
# Out:
# iter 0, ELBO: -5.08e+09
# iter 1, ELBO: -2.69e+09, delta_ELBO: 2.39e+09
# iter 2, ELBO: -2.69e+09, delta_ELBO: 5.35e+04
# iter 3, ELBO: -2.69e+09, delta_ELBO: 3.56e+04
# iter 4, ELBO: -2.69e+09, delta_ELBO: 2.50e+04
# iter 5, ELBO: -2.69e+09, delta_ELBO: 7.22e+03
# iter 6, ELBO: -2.69e+09, delta_ELBO: 2.24e+03
# iter 7, ELBO: -2.69e+09, delta_ELBO: 9.77e+02
# iter 8, ELBO: -2.69e+09, delta_ELBO: 4.50e+02
# iter 9, ELBO: -2.69e+09, delta_ELBO: 1.96e+02
# iter 10, ELBO: -2.69e+09, delta_ELBO: 8.75e+01
# iter 11, ELBO: -2.69e+09, delta_ELBO: 4.40e+01
# iter 12, ELBO: -2.69e+09, delta_ELBO: 2.50e+01
# iter 13, ELBO: -2.69e+09, delta_ELBO: 1.40e+01
# iter 14, ELBO: -2.69e+09, delta_ELBO: 7.87e+00
# iter 15, ELBO: -2.69e+09, delta_ELBO: 5.33e+00
# iter 16, ELBO: -2.69e+09, delta_ELBO: 3.02e+00
# iter 17, ELBO: -2.69e+09, delta_ELBO: 1.87e+00
# iter 18, ELBO: -2.69e+09, delta_ELBO: 1.16e+00
# iter 19, ELBO: -2.69e+09, delta_ELBO: 1.01e+00
# iter 20, ELBO: -2.69e+09, delta_ELBO: 1.47e-01
# iter 21, ELBO: -2.69e+09, delta_ELBO: 3.14e-01
# iter 22, ELBO: -2.69e+09, delta_ELBO: 1.69e-01
# iter 23, ELBO: -2.69e+09, delta_ELBO: 1.02e-01
# iter 24, ELBO: -2.69e+09, delta_ELBO: 6.46e-02
# iter 25, ELBO: -2.69e+09, delta_ELBO: 4.20e-02
# iter 26, ELBO: -2.69e+09, delta_ELBO: 5.16e-03
# Converged on iter 26

# %% [markdown]
# Plot patterns and include marker genes:

# %%
pat_genes = list()
for i in range(n_patterns):
    pat1_subset = np.array(results_patterns[0]['pattern'] == i)
    pat_genes.append(results_patterns[0].iloc[pat1_subset].iloc[np.argsort(-results_patterns[0]['membership'].iloc[pat1_subset])])

# %%
marker_genes = np.flipud(np.array(('HES1', 'CRYAB', 'VIM', 'PTN',
                          'EOMES', 'PPP1R17', 'WNT7B', 'CRYM','TBR1', 'ADRA2A', 'CPLX3', 'NPY', 'GAP43',
                          'SATB2', 'SYT4', 'SOX5', 'BCL11B',
                          'ARX', 'DLX2', 'OLIG2',
                          'CLDN5', 'SPARC','AIF1')))
pat_markers = list()
for j in range(n_patterns):
    pat_markers.append(marker_genes[[marker_genes[i] in np.array(pat_genes[j]['g']) for i in range(len(marker_genes))]])

# %%
n_topGenes = 100
n_markerGenes = 4
polynomial_order = 5

SMALL_SIZE = 18
MEDIUM_SIZE = 18
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

c_palette = ('blue', 'red', 'green', 'yellow')

fig, ax = plt.subplots(3,1,figsize=(10, 20))

for i in range(n_patterns):
    
    for j in range(n_topGenes):
        ax[i].scatter(adata.obs['VCDepth'][subset_19pcw],
                adata.layers['zscore_19pcw'][subset_19pcw, np.where(adata.var_names == pat_genes[i]['g'].iloc[j])[0][0]],
                c = 'grey', alpha = 0.1)
        x = adata.obs['VCDepth'][subset_19pcw]
        y = adata.layers['zscore_19pcw'][subset_19pcw, np.where(adata.var_names == pat_genes[i]['g'].iloc[j])[0][0]]
        ax[i].plot(np.unique(x), np.poly1d(np.polyfit(x, y, polynomial_order))(np.unique(x)),
                   c = 'grey', alpha = 0.1)
        
    for k in range(n_markerGenes):
        ax[i].scatter(adata.obs['VCDepth'][subset_19pcw],
                    adata.layers['zscore_19pcw'][subset_19pcw, np.where(adata.var_names == pat_markers[i][k])[0][0]],
                   label = pat_markers[i][k], c = c_palette[k])
        x = adata.obs['VCDepth'][subset_19pcw] 
        y = adata.layers['zscore_19pcw'][subset_19pcw, np.where(adata.var_names == pat_markers[i][k])[0][0]]
        ax[i].plot(np.unique(x), np.poly1d(np.polyfit(x, y, polynomial_order))(np.unique(x)),
                   c = c_palette[k])
    
    ax[i].set_xlabel('Cortical Depth')
    ax[i].set_ylabel('Z-score of log2(CPM + 1)')
    ax[i].legend()
    plt.savefig('../KR_NAS/publication_figures/SpatialDE_patterns.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-179-ad2173ef56b4> in <module>
#      42     ax[i].set_ylabel('Z-score of log2(CPM + 1)')
#      43     ax[i].legend()
# ---> 44     plt.savefig('publication_figures/SpatialDE_patterns.pdf')
#
# ~/.local/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~/.local/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2103                     orientation=orientation,
#    2104                     bbox_inches_restore=_bbox_inches_restore,
# -> 2105                     **kwargs)
#    2106             finally:
#    2107                 if bbox_inches and restore_bbox:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata, **kwargs)
#    2539             file = filename._file
#    2540         else:
# -> 2541             file = PdfFile(filename, metadata=metadata)
#    2542         try:
#    2543             file.newPage(width, height)
#
# ~/.local/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, metadata)
#     457         self.original_file_like = None
#     458         self.tell_base = 0
# --> 459         fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     460         if not opened:
#     461             try:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'publication_figures/SpatialDE_patterns.pdf'

# %%
# Out:
# 2343

# %% [markdown]
# Check spatially varying genes for cell type markers:

# %%
marker_genes[[marker_genes[i] in genes_significant_fdr for i in range(len(marker_genes))]]
# Out:
# array(['SPARC', 'CLDN5', 'OLIG2', 'DLX2', 'ARX', 'BCL11B', 'SOX5', 'SYT4',
#        'SATB2', 'GAP43', 'NPY', 'ADRA2A', 'TBR1', 'CRYM', 'PPP1R17',
#        'EOMES', 'PTN', 'VIM', 'CRYAB', 'HES1'], dtype='<U7')

# %% [markdown]
# Get genes that covary with cell type markers:

# %%
correlation_matrix = np.corrcoef(adata.layers['CPM'][:,[adata.var_names[i] in genes_significant_fdr
                                                    for i in range(len(adata.var_names))]][subset_19pcw,:].T)

# %%
n_topGenes = 1
topGenes = []
markerGenes = []
for i in range(len(marker_genes)):
    if marker_genes[i] in input_genes:
        index = np.where(input_genes == marker_genes[i])[0][0]
        topGenes.append(np.argsort(-1*correlation_matrix[index,:])[:n_topGenes])
        markerGenes.append(marker_genes[i])
topGenes_dic = dict(zip(marker_genes, topGenes))

# %% [markdown]
# Now plot spatially varying cell type markers and their covarying genes:

# %%
SMALL_SIZE = 18
MEDIUM_SIZE = 18
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

for i in range(len(topGenes_dic.keys())):
    for j in range(n_topGenes):
        plt.scatter(adata.obs['VCDepth'][subset_19pcw],
                adata.layers['zscore_19pcw'][subset_19pcw, topGenes_dic[list(topGenes_dic.keys())[i]][j]],
                c = 'grey', alpha = 0.1)
    plt.scatter(adata.obs['VCDepth'][subset_19pcw],
                adata.layers['zscore_19pcw'][subset_19pcw, adata.var_names == list(topGenes_dic.keys())[i]],
               label = list(topGenes_dic.keys())[i], c = 'red')
    plt.xlabel('Cortical Depth')
    plt.ylabel('Z-score of log2(CPM + 1)')
    plt.legend()
    plt.show()
