# %% [markdown]
# Make a colour code for cell types and markers that we use for figures:

# %%
import pandas as pd
import pickle as pickle

# %%
celltypes = ['SPN', 'End', 'ExDp1', 'ExDp2', 'ExM', 'ExM-U', 'ExN', 'InCGE', 'InMGE', 'IP',
       'Mic', 'OPC', 'oRG', 'Per', 'PgG2M', 'PgS', 'vRG']

# %%
colourCode = pd.DataFrame(index = celltypes, columns = ('FullName', 'Markers', 'Colour'))

# %%
colourCode.loc['SPN','FullName'] = 'Subplate Neurons'
colourCode.loc['ExDp1','FullName'] = 'Excitatory deep layer 1'
colourCode.loc['ExDp2','FullName'] = 'Excitatory deep layer 2'
colourCode.loc['ExM','FullName'] = 'Maturing Excitatory'
colourCode.loc['ExM-U','FullName'] = 'Maturing excitatory upper enriched'
colourCode.loc['ExN','FullName'] = 'Migrating excitatory'
colourCode.loc['InCGE','FullName'] = 'Interneuron CGE'
colourCode.loc['InMGE','FullName'] = 'Interneuron MGE'
colourCode.loc['IP','FullName'] = 'Intermediate progenitor cell'
colourCode.loc['PgG2M','FullName'] = 'Cycling progenitors (G2/M Phase)'
colourCode.loc['PgS','FullName'] = 'Cycling progenitors (S phase)'
colourCode.loc['Mic','FullName'] = 'Microglia'
colourCode.loc['OPC','FullName'] = 'Oligondendrocyte progenitor cell'
colourCode.loc['oRG','FullName'] = 'Outer radial glia'
colourCode.loc['Per','FullName'] = 'Pericyte'
colourCode.loc['vRG','FullName'] = 'Ventricular radial glia'
colourCode.loc['End','FullName'] = 'Endothelial cell'

# %%
colourCode.loc['SPN','Colour'] = 'salmon'
colourCode.loc['ExDp1','Colour'] = 'deepskyblue'
colourCode.loc['ExDp2','Colour'] = 'blue'
colourCode.loc['ExM','Colour'] = 'gold'
colourCode.loc['ExM-U','Colour'] = 'yellow'
colourCode.loc['ExN','Colour'] = 'darkorange'
colourCode.loc['InCGE','Colour'] = 'darkgray'
colourCode.loc['InMGE','Colour'] = 'dimgray'
colourCode.loc['IP','Colour'] = 'darkviolet'
colourCode.loc['PgG2M','Colour'] = 'rebeccapurple'
colourCode.loc['PgS','Colour'] = 'violet'
colourCode.loc['Mic','Colour'] = 'indianred'
colourCode.loc['OPC','Colour'] = 'lightcoral'
colourCode.loc['oRG','Colour'] = 'red'
colourCode.loc['Per','Colour'] = 'darkgreen'
colourCode.loc['vRG','Colour'] = 'lightgreen'
colourCode.loc['End','Colour'] = 'darkcyan'

# %%
colourCode.loc['SPN','Markers'] = ('WNT7B', 'CRYM', 'TBR1')
colourCode.loc['ExDp1','Markers'] = ('NEUROD6', 'STMN2', 'SOX5', 'TBR1')
colourCode.loc['ExDp2','Markers'] = ('STMN2', 'SOX5', 'TBR1', 'BCL11B')
colourCode.loc['ExM','Markers'] = ('NEUROD6', 'STMN2', 'SATB2')
colourCode.loc['ExM-U','Markers'] = ('NEUROD6', 'STMN2')
colourCode.loc['ExN','Markers'] = ('NEUROD6', 'STMN2')
colourCode.loc['InCGE','Markers'] = ('SOX2', 'STMN2', 'CALB2', 'DLX2', 'DLX1')
colourCode.loc['InMGE','Markers'] = ('SOX2', 'STMN2', 'SST', 'DLX2', 'DLX1')
colourCode.loc['IP','Markers'] = ('EOMES', 'PPP1R17')
colourCode.loc['PgG2M','Markers'] = ('SOX2', 'EOMES')
colourCode.loc['PgS','Markers'] = ('SOX2', 'EOMES')
colourCode.loc['Mic','Markers'] = ('CX3CR1', 'AIF1')
colourCode.loc['OPC','Markers'] = ('SOX2', 'OLIG2', 'OLIG1')
colourCode.loc['oRG','Markers'] = ('HOPX', 'SOX2', 'VIM', 'PTN')
colourCode.loc['Per','Markers'] = ('RGS5')
colourCode.loc['vRG','Markers'] = ('CRYAB', 'SOX2', 'HES1', 'VIM')
colourCode.loc['End','Markers'] = ('CLDN5', 'ITM2A')

# %%
colourCode
# Out:
#                                  FullName                           Markers  \
# SPN                      Subplate Neurons               (WNT7B, CRYM, TBR1)
# End                      Endothelial cell                    (CLDN5, ITM2A)
# ExDp1             Excitatory deep layer 1      (NEUROD6, STMN2, SOX5, TBR1)
# ExDp2             Excitatory deep layer 2       (STMN2, SOX5, TBR1, BCL11B)
# ExM                   Maturing Excitatory           (NEUROD6, STMN2, SATB2)
# ExM-U  Maturing excitatory upper enriched                  (NEUROD6, STMN2)
# ExN                  Migrating excitatory                  (NEUROD6, STMN2)
# InCGE                     Interneuron CGE  (SOX2, STMN2, CALB2, DLX2, DLX1)
# InMGE                     Interneuron MGE    (SOX2, STMN2, SST, DLX2, DLX1)
# IP           Intermediate progenitor cell                  (EOMES, PPP1R17)
# Mic                             Microglia                    (CX3CR1, AIF1)
# ...

# %%
pickle.dump(colourCode, open("/nfs/team283/aa16/KR_NAS/0_publication_figures_scripts/celltypesColourCode.p", "wb" ))
