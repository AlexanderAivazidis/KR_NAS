# %% [markdown]
# Return some statistics about negative probes:

# %%
import sys,os
path = '/nfs/team283/aa16/KR_NAS/'
os.chdir(path)
sys.path.append(path)

# %%
import pickle
import anndata
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
import seaborn as sns
import diffxpy.api as de
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
# Out:
# /nfs/users/nfs_a/aa16/.local/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
adata_wta = pickle.load(open(path + "data/nanostringWTA_fetailBrain_AnnData.p", "rb" ))

# %%
adata_genes = adata_wta[:, np.array(adata_wta.var != 'NegProbe-WTX')[:,0]]
adata_neg = adata_wta[:, np.array(adata_wta.var == 'NegProbe-WTX')[:,0]]

# %%
totalcounts1 = np.sum(adata_wta.X, axis = 1)
totalcounts2 = np.sum(adata_genes.X, axis = 1)

# %%
corrMatrix = np.corrcoef(totalcounts1, adata_neg.X.T)
print(np.mean(corrMatrix[0,1:]))
print(np.sqrt(np.var(corrMatrix[0,1:])))
# Out:
# 0.9101187420387069
# 0.04629981643708809

# %%
corrMatrix = np.corrcoef(totalcounts2, adata_neg.X.T)
print(np.mean(corrMatrix[0,1:]))
print(np.sqrt(np.var(corrMatrix[0,1:])))
# Out:
# 0.9098415471251129
# 0.046366865030593

# %%
adata_wta.X
# Out:
# array([[  6.,   0.,  48., ...,  33.,  20.,  24.],
#        [ 19.,  21., 123., ...,  36.,  35.,  28.],
#        [  7.,  22., 140., ...,  54.,  51.,  51.],
#        ...,
#        [ 25.,  34., 106., ...,  34.,  51.,  40.],
#        [ 25.,  30.,  98., ...,  50.,  51.,  43.],
#        [  8.,  14.,  36., ...,   8.,  17.,  10.]], dtype=float32)

# %%
adata_wta.obs.to_csv('/nfs/team283/aa16/KR_NAS/0_publication_tables/SupplementaryTableX_WTA-Experiment_Metadata.csv')

# %%
pd.DataFrame(data = adata_wta.X.T, index = list(adata_wta.var.index), columns = list(adata_wta.obs.index)).to_csv(
'/nfs/team283/aa16/KR_NAS/0_publication_tables/SupplementaryTableX_WTA-Experiment_ProbeCounts.csv')
# Out:
#               HCA_F_BRA8739082  HCA_F_BRA8739083  HCA_F_BRA8739084  \
# A1BG                       6.0              19.0               7.0
# A1CF                       0.0              21.0              22.0
# A2M                       48.0             123.0             140.0
# A2ML1                     19.0              17.0              22.0
# A3GALT2                    0.0               5.0               1.0
# ...                        ...               ...               ...
# NegProbe-WTX              15.0              25.0              47.0
# NegProbe-WTX              23.0              30.0              51.0
# NegProbe-WTX              33.0              36.0              54.0
# NegProbe-WTX              20.0              35.0              51.0
# NegProbe-WTX              24.0              28.0              51.0
#
#               HCA_F_BRA8739085  HCA_F_BRA8739086  HCA_F_BRA8739087  \
# A1BG                      12.0              11.0             151.0
# A1CF                      22.0              29.0             159.0
# A2M                       61.0             189.0             263.0
# A2ML1                      0.0              21.0             118.0
# A3GALT2                   13.0               8.0             108.0
# ...                        ...               ...               ...
# NegProbe-WTX              31.0              42.0             143.0
# NegProbe-WTX              33.0              51.0             238.0
# NegProbe-WTX              31.0              47.0             108.0
# NegProbe-WTX              39.0              52.0             168.0
# NegProbe-WTX              36.0              43.0             114.0
#
#               HCA_F_BRA8739088  HCA_F_BRA8739089  HCA_F_BRA8739090  \
# A1BG                     154.0               0.0               0.0
# A1CF                     180.0               0.0               0.0
# A2M                      293.0              10.0              25.0
# A2ML1                    112.0               0.0               8.0
# A3GALT2                  117.0               0.0               0.0
# ...                        ...               ...               ...
# NegProbe-WTX             150.0               5.0              15.0
# NegProbe-WTX             238.0               5.0              19.0
# NegProbe-WTX              92.0               4.0               8.0
# NegProbe-WTX             167.0               4.0              21.0
# NegProbe-WTX             110.0               0.0              18.0
#
#               HCA_F_BRA8739091  ...  HCA_F_BRA8739347  HCA_F_BRA8739348  \
# A1BG                       8.0  ...              34.0              14.0
# A1CF                      15.0  ...              48.0              13.0
# A2M                       86.0  ...             112.0              45.0
# A2ML1                     14.0  ...              61.0              13.0
# A3GALT2                    5.0  ...              33.0              21.0
# ...                        ...  ...               ...               ...
# NegProbe-WTX              43.0  ...              79.0              24.0
# NegProbe-WTX              50.0  ...              35.0               8.0
# NegProbe-WTX              56.0  ...              43.0              23.0
# NegProbe-WTX              47.0  ...              64.0              12.0
# NegProbe-WTX              32.0  ...              50.0              12.0
#
#               HCA_F_BRA8739349  HCA_F_BRA8739351  HCA_F_BRA8739353  \
# A1BG                       2.0              19.0              43.0
# A1CF                       8.0              24.0              70.0
# A2M                        9.0              41.0             129.0
# A2ML1                      5.0              13.0              63.0
# A3GALT2                    6.0              36.0              64.0
# ...                        ...               ...               ...
# NegProbe-WTX              10.0               8.0             105.0
# NegProbe-WTX               4.0              21.0              41.0
# NegProbe-WTX              10.0              32.0              73.0
# NegProbe-WTX               8.0              27.0              77.0
# NegProbe-WTX               5.0              28.0              71.0
#
#               HCA_F_BRA8739354  HCA_F_BRA8739355  HCA_F_BRA8739356  \
# A1BG                      66.0              45.0              25.0
# A1CF                      75.0              73.0              34.0
# A2M                      183.0             168.0             106.0
# A2ML1                     52.0              98.0              33.0
# A3GALT2                   68.0              96.0              39.0
# ...                        ...               ...               ...
# NegProbe-WTX             125.0              86.0              49.0
# NegProbe-WTX              56.0              43.0              23.0
# NegProbe-WTX              78.0              87.0              34.0
# NegProbe-WTX              71.0              96.0              51.0
# NegProbe-WTX              91.0             101.0              40.0
#
#               HCA_F_BRA8739357  HCA_F_BRA8739359
# A1BG                      25.0               8.0
# A1CF                      30.0              14.0
# A2M                       98.0              36.0
# A2ML1                     32.0               9.0
# A3GALT2                   54.0              12.0
# ...                        ...               ...
# NegProbe-WTX              37.0              14.0
# NegProbe-WTX              17.0              11.0
# NegProbe-WTX              50.0               8.0
# NegProbe-WTX              51.0              17.0
# NegProbe-WTX              43.0              10.0
#
# [18416 rows x 255 columns]
